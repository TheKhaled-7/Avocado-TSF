# %% [markdown]
# # **Avocado Prices TSF**

# %% [markdown]
# # Data Source From Kaggel : https://www.kaggle.com/datasets/neuromusic/avocado-prices

# %% [markdown]
# ![OIP.webp](data:image/webp;base64,...)

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
avo=pd.read_csv('/content/avocado.csv')
avo.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
#pip install prophet

# %%
from prophet import Prophet

# %%
avo.shape
# Out:
# (18249, 14)

# %%
avo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
avo.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
avo=avo.sort_values("Date")

# %%
avo.head(20)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 11569          51  2015-01-04          1.75      27365.89     9307.34
# 9593           51  2015-01-04          1.49      17723.17     1189.35
# 10009          51  2015-01-04          1.68       2896.72      161.68
# 1819           51  2015-01-04          1.52      54956.80     3013.04
# 9333           51  2015-01-04          1.64       1505.12        1.27
# 2807           51  2015-01-04          0.75     758118.95   426878.87
# 1195           51  2015-01-04          0.85    2682159.95  1837999.65
# 10269          51  2015-01-04          1.50       6329.83     3730.80
# 103            51  2015-01-04          1.00     435021.49   364302.39
# 1143           51  2015-01-04          0.80     317861.35   134003.07
# 623            51  2015-01-04          0.74    1086363.97   612795.80
# 10425          51  2015-01-04          1.82       2288.44     1438.04
# ...

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=(20,10))
plt.plot(avo['Date'],avo['AveragePrice'])

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='year',data=avo)
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %% [markdown]
# # Pre-processing Data

# %%
avo_prophet = avo[['Date','AveragePrice']]
avo_prophet
# Out:
#              Date  AveragePrice
# 11569  2015-01-04          1.75
# 9593   2015-01-04          1.49
# 10009  2015-01-04          1.68
# 1819   2015-01-04          1.52
# 9333   2015-01-04          1.64
# ...           ...           ...
# 8574   2018-03-25          1.36
# 9018   2018-03-25          0.70
# 18141  2018-03-25          1.42
# 17673  2018-03-25          1.70
# 8814   2018-03-25          1.34
#
# [18249 rows x 2 columns]

# %%
avo_prophet.columns=['ds','y']

# %%
m=Prophet()
m.fit(avo_prophet)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6fx5_qvh/8ux7ksxj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6fx5_qvh/2qajhq0w.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54199', 'data', 'file=/tmp/tmp6fx5_qvh/8ux7ksxj.json', 'init=/tmp/tmp6fx5_qvh/2qajhq0w.json', 'output', 'file=/tmp/tmp6fx5_qvh/prophet_modeluirdl0bl/prophet_model-20250727164343.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:43:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:43:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
future=m.make_future_dataframe(periods=365)
future.tail()
# Out:
#             ds
# 529 2019-03-21
# 530 2019-03-22
# 531 2019-03-23
# 532 2019-03-24
# 533 2019-03-25

# %%
forcast=m.predict(future)
forcast
# Out:
#             ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0   2015-01-04  1.501458    0.924443    1.885608     1.501458     1.501458
# 1   2015-01-11  1.496064    0.868816    1.864356     1.496064     1.496064
# 2   2015-01-18  1.490671    0.878972    1.915771     1.490671     1.490671
# 3   2015-01-25  1.485278    0.872059    1.834844     1.485278     1.485278
# 4   2015-02-01  1.479885    0.848618    1.816078     1.479885     1.479885
# ..         ...       ...         ...         ...          ...          ...
# 529 2019-03-21  1.157864    0.549155    1.592317     0.965389     1.359678
# 530 2019-03-22  1.157120    0.552585    1.632353     0.963899     1.359411
# 531 2019-03-23  1.156375    0.527211    1.576732     0.962094     1.359144
# 532 2019-03-24  1.155630    0.571650    1.563971     0.960289     1.358877
# 533 2019-03-25  1.154886    0.534492    1.597100     0.958483     1.358669
#
# ...

# %%
forcast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds      yhat  yhat_lower  yhat_upper
# 529 2019-03-21  1.071793    0.549155    1.592317
# 530 2019-03-22  1.072824    0.552585    1.632353
# 531 2019-03-23  1.074129    0.527211    1.576732
# 532 2019-03-24  1.075690    0.571650    1.563971
# 533 2019-03-25  1.077479    0.534492    1.597100

# %%
fig_forcast=m.plot(forcast,xlabel='Date',ylabel='Price')

# %%
fig_com=m.plot_components(forcast)

# %% [markdown]
# **Avocado season varies by region, but in the Northern Hemisphere, it generally runs from late fall through February**
